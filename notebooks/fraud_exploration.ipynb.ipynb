# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Mwale\\AppData\\Local\\anaconda3\\envs\\fraud_ai\\python.exe'

# %%
git add notebooks/
git commit -m "Add exploratory analysis notebook"
git push
# Out:
#   Cell In[2], line 1
#     git add notebooks/
#         ^
# SyntaxError: invalid syntax
